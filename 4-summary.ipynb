# %% [markdown]
# ## Amazon SageMaker Geospatial Capabilities

# %% [markdown]
# ![image.png](attachment:dde3aaf9-4940-4121-b776-104cedc0b1bb.png)

# %% [markdown]
# ![image.png](attachment:4015e685-1eab-4890-8c5d-ea77e8cb7117.png)
